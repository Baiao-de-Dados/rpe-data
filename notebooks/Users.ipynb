# %% [markdown]
# <a href="https://colab.research.google.com/github/Baiao-de-Dados/rpe-data/blob/main/Users.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# In the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx", replace ".." with "." in the "email" column.

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount your Google Drive to access the specified file.

# %% [markdown]
# **Reasoning**:
# Mount Google Drive to access the file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the Excel file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import the pandas library, load the Excel file into a DataFrame, and display the first few rows.

# %%
import pandas as pd

excel_file_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx"
df = pd.read_excel(excel_file_path)
display(df.head())
# Out:
#             name                         email avaliacao_type  \
# 0  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 1  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 5.0
# 1            Atender aos prazos                 5.0
# 2            Sentimento de Dono                 5.0
# 3  Resiliencia nas adversidades                 2.0
# 4                           NaN                 5.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Durante o ciclo, lidero a organização das en...       NaN     NaN
# 1  - No critério Imagem, tive uma atuação consist...       NaN     NaN
# ...

# %% [markdown]
# ## Clean the email column
#
# ### Subtask:
# Replace ".." with "." in the "email" column.

# %% [markdown]
# **Reasoning**:
# Replace ".." with "." in the "email" column using the `str.replace()` method and update the DataFrame.

# %%
df['email'] = df['email'].str.replace('..', '.', regex=False)
display(df.head())
# Out:
#             name                         email avaliacao_type  \
# 0  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 1  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 5.0
# 1            Atender aos prazos                 5.0
# 2            Sentimento de Dono                 5.0
# 3  Resiliencia nas adversidades                 2.0
# 4                           NaN                 5.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Durante o ciclo, lidero a organização das en...       NaN     NaN
# 1  - No critério Imagem, tive uma atuação consist...       NaN     NaN
# ...

# %% [markdown]
# ## Save the updated data
#
# ### Subtask:
# Save the modified DataFrame back to an Excel file, replacing the original file.

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to the specified Excel file path without including the index.

# %%
excel_file_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx"
df.to_excel(excel_file_path, index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The task successfully loaded the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx" into a pandas DataFrame.
# *   The string ".." was successfully replaced with "." in the "email" column of the DataFrame.
# *   The modified DataFrame was successfully saved back to the original Excel file path, excluding the DataFrame index.
#
# ### Insights or Next Steps
#
# *   Verify the changes in the saved Excel file to ensure the replacements in the "email" column were applied as expected.
# *   Consider implementing further data cleaning steps on the "email" column, such as removing leading/trailing spaces or ensuring a valid email format, if necessary for future analysis.

# %% [markdown]
# # Task
# Correct the email format in the 'email' column of the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx" by replacing ".." with "." and create a new Excel file named "usuarios.xlsx" in the same folder containing the 'name' and corrected 'email' columns from the original file, plus a new 'password' column generated by concatenating the 'name', "rocketcorp", and "2024.1" strings.

# %% [markdown]
# ## Create a new dataframe
#
# ### Subtask:
# Create a new DataFrame with the 'name' and 'email' columns from the original DataFrame.

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame with the 'name' and 'email' columns from the original DataFrame and display the first few rows.

# %%
df_users = df[['name', 'email']].copy()
display(df_users.head())
# Out:
#             name                         email
# 0  vitor.gabriel  vitor.gabriel@rocketcorp.com
# 1  vitor.gabriel  vitor.gabriel@rocketcorp.com
# 2  vitor.gabriel  vitor.gabriel@rocketcorp.com
# 3  vitor.gabriel  vitor.gabriel@rocketcorp.com
# 4  vitor.gabriel  vitor.gabriel@rocketcorp.com

# %% [markdown]
# ## Generate passwords
#
# ### Subtask:
# Generate passwords for each user by concatenating the 'name', "rocketcorp", and "2024.1" strings and store them in a new column named 'password' in the `df_users` DataFrame.

# %% [markdown]
# **Reasoning**:
# Generate the password column by concatenating the 'name', "rocketcorp", and "2024.1" strings and then display the first few rows of the updated DataFrame.

# %% [markdown]
# ## Remove duplicate users
#
# ### Subtask:
# Remove duplicate rows from the `df_users` DataFrame based on the 'name' and 'email' columns.

# %% [markdown]
# **Reasoning**:
# Remove duplicate rows from the `df_users` DataFrame based on the 'name' and 'email' columns using the `drop_duplicates()` method and display the first few rows of the updated DataFrame.

# %%
df_users.drop_duplicates(subset=['name', 'email'], inplace=True)
display(df_users.head())
# Out:
#                  name                             email
# 0       vitor.gabriel      vitor.gabriel@rocketcorp.com
# 23            yuri.da            yuri.da@rocketcorp.com
# 46  valentina.martins  valentina.martins@rocketcorp.com
# 69     luiza.carvalho     luiza.carvalho@rocketcorp.com
# 92      lorenzo.cunha      lorenzo.cunha@rocketcorp.com

# %%
df_users['password'] = df_users['name'] + 'rocketcorp' + '2024.1'
display(df_users.head())
# Out:
#                  name                             email  \
# 0       vitor.gabriel      vitor.gabriel@rocketcorp.com
# 23            yuri.da            yuri.da@rocketcorp.com
# 46  valentina.martins  valentina.martins@rocketcorp.com
# 69     luiza.carvalho     luiza.carvalho@rocketcorp.com
# 92      lorenzo.cunha      lorenzo.cunha@rocketcorp.com
#
#                              password
# 0       vitor.gabrielrocketcorp2024.1
# 23            yuri.darocketcorp2024.1
# 46  valentina.martinsrocketcorp2024.1
# 69     luiza.carvalhorocketcorp2024.1
# 92      lorenzo.cunharocketcorp2024.1

# %% [markdown]
# ## Save the new data
#
# ### Subtask:
# Save the `df_users` DataFrame to a new Excel file named "usuarios.xlsx" in the same folder as the original file.

# %% [markdown]
# **Reasoning**:
# Construct the full path for the new Excel file and save the `df_users` DataFrame to this path without including the index.

# %%
import os

# Extract the directory path from the original file path
original_file_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx"
output_directory = os.path.dirname(original_file_path)

# Construct the path for the new file
output_file_path = os.path.join(output_directory, "usuarios.xlsx")

# Save the df_users DataFrame to the new Excel file
df_users.to_excel(output_file_path, index=False)

print(f"New file saved to: {output_file_path}")
# Out:
# New file saved to: /content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/usuarios.xlsx

# %% [markdown]
# # Task
# Create a file named "usuarios.xlsx" with unique users from "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx" and "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2.xlsx". The file should contain 'name', 'email', and 'password' columns. Clean the 'email' column in both input files by replacing ".." with ".". Generate passwords by concatenating the 'name', "rocketcorp", and "2024.1" for users from the first file and "2024.2" for users from the second file. Ensure no duplicate users exist in the final "usuarios.xlsx" file.

# %% [markdown]
# ## Load the new data
#
# ### Subtask:
# Load the data from "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2.xlsx" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from the second Excel file into a pandas DataFrame and display the first few rows.

# %%
excel_file_path_2 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2.xlsx"
df_2 = pd.read_excel(excel_file_path_2)
display(df_2.head())
# Out:
#             name                         email avaliacao_type  \
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 1.0
# 1            Atender aos prazos                 3.0
# 2            Sentimento de Dono                 4.0
# 3  Resiliencia nas adversidades                 4.0
# 4                           NaN                 4.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Tenho dificuldade em manter o controle das t...       NaN     NaN
# 1  - Atuei de forma adequada no critério Imagem. ...       NaN     NaN
# ...

# %% [markdown]
# ## Clean the email column for the new data
#
# ### Subtask:
# Replace ".." with "." in the "email" column of the new DataFrame.

# %% [markdown]
# **Reasoning**:
# Replace ".." with "." in the "email" column of the `df_2` DataFrame.

# %%
df_2['email'] = df_2['email'].str.replace('..', '.', regex=False)
display(df_2.head())
# Out:
#             name                         email avaliacao_type  \
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 1.0
# 1            Atender aos prazos                 3.0
# 2            Sentimento de Dono                 4.0
# 3  Resiliencia nas adversidades                 4.0
# 4                           NaN                 4.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Tenho dificuldade em manter o controle das t...       NaN     NaN
# 1  - Atuei de forma adequada no critério Imagem. ...       NaN     NaN
# ...

# %% [markdown]
# ## Create a dataframe for new users
#
# ### Subtask:
# Create a new DataFrame with the 'name' and cleaned 'email' columns from the new DataFrame (`df_2`).

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame called `df_users_2` with the 'name' and 'email' columns from `df_2` and display its head.

# %%
df_users_2 = df_2[['name', 'email']].copy()
display(df_users_2.head())
# Out:
#             name                         email
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com

# %% [markdown]
# ## Generate passwords for new users
#
# ### Subtask:
# Generate passwords for the new users by concatenating the 'name', "rocketcorp", and "2024.2" strings and store them in a new column named 'password' in the `df_users_2` DataFrame.

# %% [markdown]
# **Reasoning**:
# Generate the password column for the new users by concatenating the 'name', "rocketcorp", and "2024.2" strings and then display the first few rows of the updated DataFrame.

# %%
df_users_2['password'] = df_users_2['name'] + 'rocketcorp' + '2024.2'
display(df_users_2.head())
# Out:
#             name                         email                       password
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com  lucas.gabrielrocketcorp2024.2
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com  lucas.gabrielrocketcorp2024.2
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com  lucas.gabrielrocketcorp2024.2
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com  lucas.gabrielrocketcorp2024.2
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com  lucas.gabrielrocketcorp2024.2

# %% [markdown]
# ## Load existing users
#
# ### Subtask:
# Load the existing "usuarios.xlsx" file into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the existing "usuarios.xlsx" file into a DataFrame and display the first few rows.

# %%
excel_file_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx"
output_directory = os.path.dirname(excel_file_path)
output_file_path = os.path.join(output_directory, "usuarios.xlsx")

df_existing_users = pd.read_excel(output_file_path)
display(df_existing_users.head())
# Out:
#                 name                             email  \
# 0      vitor.gabriel      vitor.gabriel@rocketcorp.com
# 1            yuri.da            yuri.da@rocketcorp.com
# 2  valentina.martins  valentina.martins@rocketcorp.com
# 3     luiza.carvalho     luiza.carvalho@rocketcorp.com
# 4      lorenzo.cunha      lorenzo.cunha@rocketcorp.com
#
#                             password
# 0      vitor.gabrielrocketcorp2024.1
# 1            yuri.darocketcorp2024.1
# 2  valentina.martinsrocketcorp2024.1
# 3     luiza.carvalhorocketcorp2024.1
# 4      lorenzo.cunharocketcorp2024.1

# %% [markdown]
# **Reasoning**:
# Concatenate the existing users DataFrame and the new users DataFrame, remove duplicate users based on 'name' and 'email', and display the first few rows.

# %%
df_all_users = pd.concat([df_existing_users, df_users_2], ignore_index=True)
df_all_users.drop_duplicates(subset=['name', 'email'], inplace=True)
display(df_all_users.head())
# Out:
#                 name                             email  \
# 0      vitor.gabriel      vitor.gabriel@rocketcorp.com
# 1            yuri.da            yuri.da@rocketcorp.com
# 2  valentina.martins  valentina.martins@rocketcorp.com
# 3     luiza.carvalho     luiza.carvalho@rocketcorp.com
# 4      lorenzo.cunha      lorenzo.cunha@rocketcorp.com
#
#                             password
# 0      vitor.gabrielrocketcorp2024.1
# 1            yuri.darocketcorp2024.1
# 2  valentina.martinsrocketcorp2024.1
# 3     luiza.carvalhorocketcorp2024.1
# 4      lorenzo.cunharocketcorp2024.1

# %% [markdown]
# **Reasoning**:
# Save the combined and deduplicated DataFrame to the "usuarios.xlsx" file, replacing the original file, and report the finish status and the dataframes.

# %%
df_all_users.to_excel(output_file_path, index=False)
print(f"Combined users saved to: {output_file_path}")
# Out:
# Combined users saved to: /content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/usuarios.xlsx

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Data from the file "2024\_2.xlsx" was successfully loaded and processed.
# *   The 'email' column in the data from "2024\_2.xlsx" was cleaned by replacing ".." with ".".
# *   A new DataFrame (`df\_users\_2`) was created containing 'name' and cleaned 'email' from "2024\_2.xlsx".
# *   Passwords were generated for users from "2024\_2.xlsx" by concatenating the user's 'name', "rocketcorp", and "2024.2".
# *   The existing "usuarios.xlsx" file was loaded, and new users were combined with existing users.
# *   Duplicate users were removed based on the combination of 'name' and 'email'.
# *   The final combined and deduplicated user list was saved back to "usuarios.xlsx".
#
# ### Insights or Next Steps
#
# *   The process successfully created a consolidated list of unique users with generated passwords.
# *   Ensure robust error handling for file operations and data inconsistencies in a production environment.

# %% [markdown]
# ## Load the data from 2025_1.xlsx
#
# ### Subtask:
# Load the data from "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1.xlsx" into a pandas DataFrame (`df_2025_1`).

# %% [markdown]
# **Reasoning**:
# Load the data from the third Excel file into a pandas DataFrame and display the first few rows.

# %%
excel_file_path_3 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1.xlsx"
df_2025_1 = pd.read_excel(excel_file_path_3)
display(df_2025_1.head())
# Out:
#              name                          email avaliacao_type  \
# 0  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 1  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 2  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 3  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 4  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 1.0
# 1            Atender aos prazos                 4.0
# 2            Sentimento de Dono                 5.0
# 3  Resiliencia nas adversidades                 4.0
# 4                           NaN                 3.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Tenho dificuldade em manter o controle das t...       NaN     NaN
# 1  - No critério Imagem, estou em processo de des...       NaN     NaN
# ...

# %% [markdown]
# ## Clean the email column for 2025_1.xlsx
#
# ### Subtask:
# Replace ".." with "." in the "email" column of the `df_2025_1` DataFrame.

# %% [markdown]
# **Reasoning**:
# Replace ".." with "." in the "email" column of the `df_2025_1` DataFrame.

# %%
df_2025_1['email'] = df_2025_1['email'].str.replace('..', '.', regex=False)
display(df_2025_1.head())
# Out:
#              name                          email avaliacao_type  \
# 0  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 1  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 2  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 3  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 4  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
#
#                        criterio  autoavaliacao_nota  \
# 0       Organização no Trabalho                 1.0
# 1            Atender aos prazos                 4.0
# 2            Sentimento de Dono                 5.0
# 3  Resiliencia nas adversidades                 4.0
# 4                           NaN                 3.0
#
#                          justificativa_autoavaliacao a360_name projeto  \
# 0  - Tenho dificuldade em manter o controle das t...       NaN     NaN
# 1  - No critério Imagem, estou em processo de des...       NaN     NaN
# ...

# %% [markdown]
# ## Create a DataFrame for 2025_1 users
#
# ### Subtask:
# Create a new DataFrame with the 'name' and cleaned 'email' columns from `df_2025_1`.

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame called `df_users_2025_1` with the 'name' and 'email' columns from `df_2025_1` and display its head.

# %%
df_users_2025_1 = df_2025_1[['name', 'email']].copy()
display(df_users_2025_1.head())
# Out:
#              name                          email
# 0  vitória.aragão  vitória.aragão@rocketcorp.com
# 1  vitória.aragão  vitória.aragão@rocketcorp.com
# 2  vitória.aragão  vitória.aragão@rocketcorp.com
# 3  vitória.aragão  vitória.aragão@rocketcorp.com
# 4  vitória.aragão  vitória.aragão@rocketcorp.com

# %% [markdown]
# ## Generate passwords for 2025_1 users
#
# ### Subtask:
# Generate passwords for the 2025_1 users by concatenating the 'name', "rocketcorp", and "2025.1" strings and store them in a new column named 'password' in the `df_users_2025_1` DataFrame.

# %% [markdown]
# **Reasoning**:
# Generate the password column for the 2025_1 users by concatenating the 'name', "rocketcorp", and "2025.1" strings and then display the first few rows of the updated DataFrame.

# %%
df_users_2025_1['password'] = df_users_2025_1['name'] + 'rocketcorp' + '2025.1'
display(df_users_2025_1.head())
# Out:
#              name                          email  \
# 0  vitória.aragão  vitória.aragão@rocketcorp.com
# 1  vitória.aragão  vitória.aragão@rocketcorp.com
# 2  vitória.aragão  vitória.aragão@rocketcorp.com
# 3  vitória.aragão  vitória.aragão@rocketcorp.com
# 4  vitória.aragão  vitória.aragão@rocketcorp.com
#
#                          password
# 0  vitória.aragãorocketcorp2025.1
# 1  vitória.aragãorocketcorp2025.1
# 2  vitória.aragãorocketcorp2025.1
# 3  vitória.aragãorocketcorp2025.1
# 4  vitória.aragãorocketcorp2025.1

# %%
df_all_users = pd.concat([df_all_users, df_users_2025_1], ignore_index=True)
df_all_users.drop_duplicates(subset=['name', 'email'], inplace=True)
display(df_all_users.head())
# Out:
#                 name                             email  \
# 0      vitor.gabriel      vitor.gabriel@rocketcorp.com
# 1            yuri.da            yuri.da@rocketcorp.com
# 2  valentina.martins  valentina.martins@rocketcorp.com
# 3     luiza.carvalho     luiza.carvalho@rocketcorp.com
# 4      lorenzo.cunha      lorenzo.cunha@rocketcorp.com
#
#                             password
# 0      vitor.gabrielrocketcorp2024.1
# 1            yuri.darocketcorp2024.1
# 2  valentina.martinsrocketcorp2024.1
# 3     luiza.carvalhorocketcorp2024.1
# 4      lorenzo.cunharocketcorp2024.1

# %% [markdown]
# **Reasoning**:
# Save the combined and deduplicated DataFrame to the "usuarios.xlsx" file, replacing the original file, and report the finish status and the dataframes.

# %%
import os

# Extract the directory path from the original file path
original_file_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1.xlsx"
output_directory = os.path.dirname(original_file_path)

# Construct the path for the new file
output_file_path = os.path.join(output_directory, "usuarios.xlsx")

df_all_users.to_excel(output_file_path, index=False)
print(f"Combined users saved to: {output_file_path}")
# Out:
# Combined users saved to: /content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/usuarios.xlsx
