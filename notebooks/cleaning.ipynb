# %% [markdown]
# <a href="https://colab.research.google.com/github/Baiao-de-Dados/rpe-data/blob/main/cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Clean the data in the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1.xlsx" by filling empty cells in a specific column with the value from the cell above and then renaming that column to 'name'.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the Excel file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the Excel file into a DataFrame.

# %%
import pandas as pd

df = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1.xlsx")

# %% [markdown]
# **Reasoning**:
# Display the first few rows of the DataFrame to verify that the data was loaded correctly.

# %%
display(df.head())
# Out:
#   Nome ( nome.sobrenome )                      Email  Ciclo (ano.semestre)  \
# 0           vitor.gabriel  vitor.gabriel@example.com                2024.1
# 1                     NaN                        NaN                   NaN
# 2                     NaN                        NaN                   NaN
# 3                     NaN                        NaN                   NaN
# 4                     NaN                        NaN                   NaN
#
#      Unidade          Original_Filename Original_Sheetname         CRITÉRIO  \
# 0  São Paulo  VITOR_GABRIEL_2024_1.XLSX             Perfil              NaN
# 1        NaN  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação      Organização
# 2        NaN  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação           Imagem
# 3        NaN  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação       Iniciativa
# 4        NaN  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação  Comprometimento
#
# ...

# %% [markdown]
# ## Fill empty cells
#
# ### Subtask:
# Fill the empty cells in the specified column with the value from the cell above.

# %% [markdown]
# **Reasoning**:
# Fill the empty cells in the 'Nome ( nome.sobrenome )' column using the forward fill method.

# %%
df['Nome ( nome.sobrenome )'] = df['Nome ( nome.sobrenome )'].fillna(method='ffill')
display(df.head())
# Out:
# /tmp/ipython-input-3-4166084460.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Nome ( nome.sobrenome )'] = df['Nome ( nome.sobrenome )'].fillna(method='ffill')
#   Nome ( nome.sobrenome )                      Email  Ciclo (ano.semestre)  \
# 0           vitor.gabriel  vitor.gabriel@example.com                2024.1
# 1           vitor.gabriel                        NaN                   NaN
# 2           vitor.gabriel                        NaN                   NaN
# 3           vitor.gabriel                        NaN                   NaN
# 4           vitor.gabriel                        NaN                   NaN
#
#      Unidade          Original_Filename Original_Sheetname         CRITÉRIO  \
# 0  São Paulo  VITOR_GABRIEL_2024_1.XLSX             Perfil              NaN
# 1        NaN  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação      Organização
# ...

# %% [markdown]
# ## Rename the column
#
# ### Subtask:
# Rename the column 'Nome ( nome.sobrenome )' to 'name'.

# %% [markdown]
# **Reasoning**:
# Rename the specified column and display the head of the dataframe to confirm the change.

# %%
df.rename(columns={'Nome ( nome.sobrenome )': 'name'}, inplace=True)
display(df.head())
# Out:
#             name                      Email  Ciclo (ano.semestre)    Unidade  \
# 0  vitor.gabriel  vitor.gabriel@example.com                2024.1  São Paulo
# 1  vitor.gabriel                        NaN                   NaN        NaN
# 2  vitor.gabriel                        NaN                   NaN        NaN
# 3  vitor.gabriel                        NaN                   NaN        NaN
# 4  vitor.gabriel                        NaN                   NaN        NaN
#
#            Original_Filename Original_Sheetname         CRITÉRIO  \
# 0  VITOR_GABRIEL_2024_1.XLSX             Perfil              NaN
# 1  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação      Organização
# 2  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação           Imagem
# 3  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação       Iniciativa
# 4  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação  Comprometimento
#
#                                      DESCRIÇÃO GERAL  AUTO-AVALIAÇÃO  \
# ...

# %% [markdown]
# ## Save the cleaned data
#
# ### Subtask:
# Save the modified DataFrame back to a new Excel file or overwrite the original.

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned.xlsx"
df.to_excel(output_path, index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Empty cells in the 'Nome ( nome.sobrenome )' column were successfully filled using the forward-fill method.
# *   The column 'Nome ( nome.sobrenome )' was successfully renamed to 'name'.
# *   The cleaned data was saved to a new Excel file named `2024_1_cleaned.xlsx` without the DataFrame index.
#
# ### Insights or Next Steps
#
# *   The cleaned data in `2024_1_cleaned.xlsx` is now ready for further analysis or merging with other datasets.

# %% [markdown]
# # Task
# Clean the data in the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1.xlsx" by filling empty cells in a specific column with the value from the cell above, renaming this column to 'name', and then cleaning the 'name' column to keep only 'nome.sobrenome' from values that are in the format 'nome..sobrenome'.

# %% [markdown]
# ## Clean the 'name' column
#
# ### Subtask:
# Remove the '..sobrenome' part from the values in the 'name' column, keeping only 'nome.sobrenome'.

# %% [markdown]
# **Reasoning**:
# Clean the 'name' column by removing '..sobrenome' and display the head of the dataframe to verify the changes.

# %%
df['name'] = df['name'].str.replace(r'\.\.sobrenome', '', regex=True)
display(df.head())
# Out:
#             name                      Email  Ciclo (ano.semestre)    Unidade  \
# 0  vitor.gabriel  vitor.gabriel@example.com                2024.1  São Paulo
# 1  vitor.gabriel                        NaN                   NaN        NaN
# 2  vitor.gabriel                        NaN                   NaN        NaN
# 3  vitor.gabriel                        NaN                   NaN        NaN
# 4  vitor.gabriel                        NaN                   NaN        NaN
#
#            Original_Filename Original_Sheetname         CRITÉRIO  \
# 0  VITOR_GABRIEL_2024_1.XLSX             Perfil              NaN
# 1  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação      Organização
# 2  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação           Imagem
# 3  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação       Iniciativa
# 4  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação  Comprometimento
#
#                                      DESCRIÇÃO GERAL  AUTO-AVALIAÇÃO  \
# ...

# %% [markdown]
# ## Save the cleaned data
#
# ### Subtask:
# Save the modified DataFrame back to a new Excel file or overwrite the original.

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned.xlsx"
df.to_excel(output_path, index=False)

# %%
# prompt: se algum name estiver com .. subistitua por .

df['name'] = df['name'].str.replace(r'\.\.', '.', regex=True)
display(df.head())
# ## Save the cleaned data
#
# ### Subtask:
# Save the modified DataFrame back to a new Excel file or overwrite the original.
#
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.
#
#
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned.xlsx"
df.to_excel(output_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-943795001.py in <cell line: 0>()
#       2
#       3 df['name'] = df['name'].str.replace(r'\.\.', '.', regex=True)
# ----> 4 display(df())
#       5 # ## Save the cleaned data
#       6 #
#
# TypeError: 'DataFrame' object is not callable

# %%
df
# Out:
#               name                      Email  Ciclo (ano.semestre)  \
# 0    vitor.gabriel  vitor.gabriel@example.com                2024.1
# 1    vitor.gabriel                        NaN                   NaN
# 2    vitor.gabriel                        NaN                   NaN
# 3    vitor.gabriel                        NaN                   NaN
# 4    vitor.gabriel                        NaN                   NaN
# ..             ...                        ...                   ...
# 355     davi.lucas                        NaN                   NaN
# 356     davi.lucas                        NaN                   NaN
# 357     davi.lucas                        NaN                   NaN
# 358     davi.lucas                        NaN                   NaN
# 359     davi.lucas                        NaN                   NaN
#
#        Unidade          Original_Filename       Original_Sheetname  \
# 0    São Paulo  VITOR_GABRIEL_2024_1.XLSX                   Perfil
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The 'name' column was successfully cleaned by removing the '..sobrenome' substring from the values.
# *   The cleaned data was saved to a new Excel file named '2024\_1\_cleaned.xlsx'.
#
# ### Insights or Next Steps
#
# *   The cleaning process was effective in standardizing the 'name' column format.
# *   The cleaned data is now ready for further analysis or merging with other datasets.

# %%
# prompt: fazer o mesmo com a coluna email de se tiver vazio subistituir para o email de cima

# Task
# Clean the data in the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1.xlsx" by filling empty cells in the 'Email' column with the value from the cell above.
# ## Fill empty cells in the 'Email' column
#
# ### Subtask:
# Fill the empty cells in the 'Email' column with the value from the cell above.
#
# **Reasoning**:
# Fill the empty cells in the 'Email' column using the forward fill method.
#
#
df['Email'] = df['Email'].fillna(method='ffill')
display(df.head())
# ## Save the cleaned data
#
# ### Subtask:
# Save the modified DataFrame back to a new Excel file or overwrite the original.
#
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.
#
#
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned.xlsx"
df.to_excel(output_path, index=False)
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Empty cells in the 'Email' column were successfully filled using the forward-fill method.
# *   The cleaned data was saved to a new Excel file named '2024\_1\_cleaned.xlsx'.
#
# ### Insights or Next Steps
#
# *   The 'Email' column is now consistent with filled-in values.
# *   The cleaned data is ready for further analysis or merging.
#
# Out:
# /tmp/ipython-input-13-1498650154.py:14: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Email'] = df['Email'].fillna(method='ffill')
#             name                      Email  Ciclo (ano.semestre)    Unidade  \
# 0  vitor.gabriel  vitor.gabriel@example.com                2024.1  São Paulo
# 1  vitor.gabriel  vitor.gabriel@example.com                   NaN        NaN
# 2  vitor.gabriel  vitor.gabriel@example.com                   NaN        NaN
# 3  vitor.gabriel  vitor.gabriel@example.com                   NaN        NaN
# 4  vitor.gabriel  vitor.gabriel@example.com                   NaN        NaN
#
#            Original_Filename Original_Sheetname         CRITÉRIO  \
# 0  VITOR_GABRIEL_2024_1.XLSX             Perfil              NaN
# 1  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação      Organização
# 2  VITOR_GABRIEL_2024_1.XLSX      Autoavaliação           Imagem
# ...

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned.xlsx"
df.to_excel(output_path, index=False)

# %%
# prompt: Usando o DataFrame df: da drop nas colunas: ciclo, unidade, Original_Filename, DESCRIÇÃO GERAL, DESCRIÇÃO NOTA, VOCÊ FICARIA MOTIVADO EM TRABALHAR NOVAMENTE COM ESTE COLABORADOR

# Dropping the specified columns from the dataframe
df = df.drop(columns=['Ciclo (ano.semestre)', 'Unidade', 'Original_Filename', 'DESCRIÇÃO GERAL', 'DESCRIÇÃO NOTA', 'VOCÊ FICARIA MOTIVADO EM TRABALHAR NOVAMENTE COM ESTE COLABORADOR'])

# %%
# prompt: salvar no excel

output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned_final.xlsx"
df.to_excel(output_path, index=False)

# %%
# prompt: substituir todos os email @example ou @empresa por @rocketcorp

df['Email'] = df['Email'].str.replace(r'@example\.\w+', '@rocketcorp', regex=True)
df['Email'] = df['Email'].str.replace(r'@empresa\.\w+', '@rocketcorp', regex=True)
display(df.head())
# Out:
#             name                     Email Original_Sheetname  \
# 0  vitor.gabriel  vitor.gabriel@rocketcorp             Perfil
# 1  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
#
#           CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0              NaN             NaN
# 1      Organização             5.0
# 2           Imagem             5.0
# 3       Iniciativa             5.0
# 4  Comprometimento             2.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0                                                NaN
# 1  - Durante o ciclo, lidero a organização das en...
# 2  - No critério Imagem, tive uma atuação consist...
# 3  - No critério Iniciativa, tive uma atuação con...
# 4  - No critério Comprometimento, estou em proces...
#
# ...

# %%
# prompt: dropar todas as linhas que tiverem escrita perfil

df = df[~df.apply(lambda row: row.astype(str).str.contains('perfil', case=False).any(), axis=1)]
display(df.head())
# Out:
#             name                     Email Original_Sheetname  \
# 1  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
# 5  vitor.gabriel  vitor.gabriel@rocketcorp      Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 1                   Organização             5.0
# 2                        Imagem             5.0
# 3                    Iniciativa             5.0
# 4               Comprometimento             2.0
# 5  Relacionamento Inter-Pessoal             5.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 1  - Durante o ciclo, lidero a organização das en...
# 2  - No critério Imagem, tive uma atuação consist...
# 3  - No critério Iniciativa, tive uma atuação con...
# ...

# %%
# prompt: mudar o nome da coluna Original_Sheetname por avaliacao

df.rename(columns={'Original_Sheetname': 'avaliacao'}, inplace=True)
display(df.head())
# Out:
# /tmp/ipython-input-25-3682113647.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Original_Sheetname': 'avaliacao'}, inplace=True)
#             name                     Email      avaliacao  \
# 1  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 5  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 1                   Organização             5.0
# 2                        Imagem             5.0
# 3                    Iniciativa             5.0
# 4               Comprometimento             2.0
# ...

# %% [markdown]
# # Task
# Update the 'CRITÉRIO' column in the current DataFrame using the mapping from the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/De-para de Critérios.xlsx" and save the updated DataFrame to a new Excel file.

# %% [markdown]
# ## Load the criteria mapping data
#
# ### Subtask:
# Load the Excel file "/content/drive/MyDrive/Untitled Folder/ciclos/De-para de Critérios.xlsx" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the Excel file containing the criteria mapping into a pandas DataFrame and display the head to verify.

# %%
df_criteria = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/De-para de Critérios.xlsx")
display(df_criteria.head())
# Out:
#    Critério Antigo                 Critério Novo
# 0      Organização       Organização no Trabalho
# 1           Imagem            Atender aos prazos
# 2       Iniciativa            Sentimento de Dono
# 3  Comprometimento  Resiliencia nas adversidades
# 4    Flexibilidade                           NaN

# %% [markdown]
# ## Create a mapping dictionary
#
# ### Subtask:
# Create a dictionary from the loaded DataFrame that maps the old criteria names to the new criteria names.

# %% [markdown]
# **Reasoning**:
# Create a dictionary from the `df_criteria` DataFrame by mapping 'Critério Antigo' to 'Critério Novo' and display the dictionary.

# %%
criteria_mapping = dict(zip(df_criteria['Critério Antigo'], df_criteria['Critério Novo']))
display(criteria_mapping)
# Out:
# {'Organização': 'Organização no Trabalho',
#  'Imagem': 'Atender aos prazos',
#  'Iniciativa': 'Sentimento de Dono',
#  'Comprometimento': 'Resiliencia nas adversidades',
#  'Flexibilidade': nan,
#  'Aprendizagem Contínua': 'Capacidade de aprender',
#  'Trabalho em Equipe': 'Ser "team player"',
#  'Relacionamento Inter-Pessoal': nan,
#  'Produtividade': 'Fazer mais com menos',
#  'Qualidade': 'Entregar com qualidade',
#  'Foco no Cliente': nan,
#  'Criatividade e Inovação': 'Pensar fora da caixa',
#  'Gestão de Pessoas*': 'Gente',
#  'Gestão de Projetos*': 'Resultados',
#  'Gestão Organizacional*': 'Evolução da Rocket Cor',
#  'Novos Clientes**': nan,
#  'Novos Projetos**': nan,
#  'Novos Produtos ou Serviços**': nan}

# %% [markdown]
# ## Update the 'critério' column
#
# ### Subtask:
# Use the mapping dictionary to update the values in the 'CRITÉRIO' column of your current DataFrame (`df`).

# %% [markdown]
# **Reasoning**:
# Update the 'CRITÉRIO' column using the mapping dictionary and display the head of the dataframe to verify the changes.

# %%
df['CRITÉRIO'] = df['CRITÉRIO'].map(criteria_mapping)
display(df.head())
# Out:
# /tmp/ipython-input-28-4051509232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CRITÉRIO'] = df['CRITÉRIO'].map(criteria_mapping)
#             name                     Email      avaliacao  \
# 1  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 5  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 1       Organização no Trabalho             5.0
# 2            Atender aos prazos             5.0
# 3            Sentimento de Dono             5.0
# ...

# %% [markdown]
# ## Save the updated dataframe
#
# ### Subtask:
# Save the modified DataFrame to a new Excel file.

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned_final.xlsx"
df.to_excel(output_path, index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   A mapping dictionary was successfully created from the "Critério Antigo" and "Critério Novo" columns of the loaded Excel file.
# *   The "CRITÉRIO" column in the main DataFrame was updated using this mapping dictionary.
# *   The updated DataFrame was successfully saved to a new Excel file at `/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_1_cleaned_final.xlsx`.
#
# ### Insights or Next Steps
#
# *   Verify the saved Excel file to ensure the "CRITÉRIO" column has been updated as expected, particularly checking rows where the original criteria might not have had a mapping.
# *   Consider addressing the `SettingWithCopyWarning` in future operations by using `.loc` for column assignment to improve code robustness.

# %% [markdown]
# # Task
# Apply the same data cleaning and transformation steps, including updating the 'CRITÉRIO' column based on the mapping in "/content/drive/MyDrive/Untitled Folder/ciclos/De-para de Critérios.xlsx", to the Excel files "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_2.xlsx" and "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2025_1.xlsx". Save the cleaned data for each file.

# %% [markdown]
# ## Process 2024 2.xlsx
#
# ### Subtask:
# Apply all the cleaning steps (load, fill empty 'name' cells, rename column, clean 'name' column, fill empty 'Email' cells, replace email domains, drop columns, rename 'Original_Sheetname' to 'avaliacao', update 'CRITÉRIO' using mapping) to the file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_2.xlsx".

# %% [markdown]
# **Reasoning**:
# Load the data, apply the specified cleaning and transformation steps to the DataFrame, and display the head.

# %%
df_2024_2 = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_2.xlsx")
df_2024_2['Nome ( nome.sobrenome )'] = df_2024_2['Nome ( nome.sobrenome )'].ffill()
df_2024_2.rename(columns={'Nome ( nome.sobrenome )': 'name'}, inplace=True)
df_2024_2['name'] = df_2024_2['name'].str.replace(r'\.\.', '.', regex=True)
df_2024_2['Email'] = df_2024_2['Email'].ffill()
df_2024_2['Email'] = df_2024_2['Email'].str.replace(r'@example\.\w+', '@rocketcorp', regex=True)
df_2024_2['Email'] = df_2024_2['Email'].str.replace(r'@empresa\.\w+', '@rocketcorp', regex=True)
df_2024_2 = df_2024_2.drop(columns=['Ciclo (ano.semestre)', 'Unidade', 'Original_Filename', 'DESCRIÇÃO GERAL', 'DESCRIÇÃO NOTA', 'VOCÊ FICARIA MOTIVADO EM TRABALHAR NOVAMENTE COM ESTE COLABORADOR'])
df_2024_2.rename(columns={'Original_Sheetname': 'avaliacao'}, inplace=True)
df_2024_2.loc[:, 'CRITÉRIO'] = df_2024_2['CRITÉRIO'].map(criteria_mapping)
display(df_2024_2.head())
# Out:
#             name                     Email      avaliacao  \
# 0  lucas.gabriel  lucas.gabriel@rocketcorp         Perfil
# 1  lucas.gabriel  lucas.gabriel@rocketcorp  Autoavaliação
# 2  lucas.gabriel  lucas.gabriel@rocketcorp  Autoavaliação
# 3  lucas.gabriel  lucas.gabriel@rocketcorp  Autoavaliação
# 4  lucas.gabriel  lucas.gabriel@rocketcorp  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0                           NaN             NaN
# 1       Organização no Trabalho             1.0
# 2            Atender aos prazos             3.0
# 3            Sentimento de Dono             4.0
# 4  Resiliencia nas adversidades             4.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0                                                NaN
# 1  - Tenho dificuldade em manter o controle das t...
# 2  - Atuei de forma adequada no critério Imagem. ...
# 3  - No critério Iniciativa, estou em processo de...
# ...

# %% [markdown]
# **Reasoning**:
# The cleaning and transformation steps for the 2024_2 file are complete. Save the modified DataFrame to a new Excel file.

# %%
output_path_2024_2 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_2_cleaned_final.xlsx"
df_2024_2.to_excel(output_path_2024_2, index=False)

# %% [markdown]
# ## Save cleaned 2024 2.xlsx
#
# ### Subtask:
# Save the cleaned DataFrame from "2024_2.xlsx" to a new Excel file.

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path_2024_2 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2024_2_cleaned_final.xlsx"
df_2024_2.to_excel(output_path_2024_2, index=False)

# %% [markdown]
# ## Process 2025 1.xlsx
#
# ### Subtask:
# Apply all the cleaning steps (load, fill empty 'name' cells, rename column, clean 'name' column, fill empty 'Email' cells, replace email domains, drop columns, rename 'Original_Sheetname' to 'avaliacao', update 'CRITÉRIO' using mapping) to the file "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2025_1.xlsx".

# %% [markdown]
# **Reasoning**:
# Apply all the specified cleaning steps to the 2025_1.xlsx file.

# %%
df_2025_1 = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2025_1.xlsx")
df_2025_1['Nome ( nome.sobrenome )'] = df_2025_1['Nome ( nome.sobrenome )'].ffill()
df_2025_1.rename(columns={'Nome ( nome.sobrenome )': 'name'}, inplace=True)
df_2025_1['name'] = df_2025_1['name'].str.replace(r'\.\.', '.', regex=True)
df_2025_1['Email'] = df_2025_1['Email'].ffill()
df_2025_1['Email'] = df_2025_1['Email'].str.replace(r'@example\.\w+', '@rocketcorp', regex=True)
df_2025_1['Email'] = df_2025_1['Email'].str.replace(r'@empresa\.\w+', '@rocketcorp', regex=True)
df_2025_1 = df_2025_1.drop(columns=['Ciclo (ano.semestre)', 'Unidade', 'Original_Filename', 'DESCRIÇÃO GERAL', 'DESCRIÇÃO NOTA', 'VOCÊ FICARIA MOTIVADO EM TRABALHAR NOVAMENTE COM ESTE COLABORADOR'])
df_2025_1.rename(columns={'Original_Sheetname': 'avaliacao'}, inplace=True)
df_2025_1.loc[:, 'CRITÉRIO'] = df_2025_1['CRITÉRIO'].map(criteria_mapping)
display(df_2025_1.head())
# Out:
#              name                      Email      avaliacao  \
# 0  vitória.aragão  vitória.aragão@rocketcorp         Perfil
# 1  vitória.aragão  vitória.aragão@rocketcorp  Autoavaliação
# 2  vitória.aragão  vitória.aragão@rocketcorp  Autoavaliação
# 3  vitória.aragão  vitória.aragão@rocketcorp  Autoavaliação
# 4  vitória.aragão  vitória.aragão@rocketcorp  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0                           NaN             NaN
# 1       Organização no Trabalho             1.0
# 2            Atender aos prazos             4.0
# 3            Sentimento de Dono             5.0
# 4  Resiliencia nas adversidades             4.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0                                                NaN
# 1  - Tenho dificuldade em manter o controle das t...
# 2  - No critério Imagem, estou em processo de des...
# 3  - No critério Iniciativa, tive uma atuação con...
# ...

# %% [markdown]
# **Reasoning**:
# Save the cleaned 2025_1 DataFrame to a new Excel file.

# %%
output_path_2025_1 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2025_1_cleaned_final.xlsx"
df_2025_1.to_excel(output_path_2025_1, index=False)

# %% [markdown]
# ## Save cleaned 2025 1.xlsx
#
# ### Subtask:
# Save cleaned 2025 1.xlsx

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/2025_1_cleaned_final.xlsx"
df_2025_1.to_excel(output_path, index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The data cleaning and transformation steps were successfully applied to both the "2024\_2.xlsx" and "2025\_1.xlsx" files.
# *   Missing values in the 'Nome ( nome.sobrenome )' and 'Email' columns were handled using forward fill in both datasets.
# *   Column renamings (from 'Nome ( nome.sobrenome )' to 'name' and 'Original\_Sheetname' to 'avaliacao') were successfully executed for both files.
# *   The 'name' column was cleaned by replacing '..' with '.' in both datasets.
# *   Email domains '@example.\w+' and '@empresa.\w+' were consistently replaced with '@rocketcorp' in the 'Email' column for both files.
# *   Identical sets of irrelevant columns ('Ciclo (ano.semestre)', 'Unidade', 'Original\_Filename', 'DESCRIÇÃO GERAL', 'DESCRIÇÃO NOTA', 'VOCÊ FICARIA MOTIVADO EM TRABALHAR NOVAMENTE COM ESTE COLABORADOR') were dropped from both dataframes.
# *   The 'CRITÉRIO' column was successfully updated in both files based on the external `criteria_mapping`.
# *   The cleaned dataframes for both "2024\_2.xlsx" and "2025\_1.xlsx" were saved to new Excel files named "2024\_2\_cleaned\_final.xlsx" and "2025\_1\_cleaned\_final.xlsx" respectively, excluding the index.
#
# ### Insights or Next Steps
#
# *   The consistent application of cleaning steps ensures uniformity across the two datasets, which is crucial for subsequent analysis or merging.
# *   The cleaned datasets are now prepared for further analysis or combination, such as merging them based on common keys like 'name' and 'Email'.

# %% [markdown]
# # Task
# Update the 'Email' column in the files "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1_cleaned_final.xlsx", "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2_cleaned_final.xlsx", and "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1_cleaned_final.xlsx" by adding ".com" to any entries that are missing it, and save the updated files.

# %% [markdown]
# ## Load cleaned 2024 1.xlsx
#
# ### Subtask:
# Load the cleaned "2024_1_cleaned_final.xlsx" file into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the Excel file into a pandas DataFrame and display the head.

# %%
df_2024_1 = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1_cleaned_final.xlsx")
display(df_2024_1.head())
# Out:
#             name                     Email      avaliacao  \
# 0  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 1  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0       Organização no Trabalho             5.0
# 1            Atender aos prazos             5.0
# 2            Sentimento de Dono             5.0
# 3  Resiliencia nas adversidades             2.0
# 4                           NaN             5.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0  - Durante o ciclo, lidero a organização das en...
# 1  - No critério Imagem, tive uma atuação consist...
# 2  - No critério Iniciativa, tive uma atuação con...
# 3  - No critério Comprometimento, estou em proces...
# ...

# %% [markdown]
# ## Add .com to email column in 2024 1.xlsx
#
# ### Subtask:
# Add ".com" to the 'Email' column for entries that are missing it in the 2024_1 DataFrame.

# %% [markdown]
# **Reasoning**:
# Add ".com" to entries in the 'Email' column that do not end with ".com" in the df_2024_1 DataFrame and display the head to verify.

# %%
df_2024_1['Email'] = df_2024_1['Email'].apply(lambda x: x if pd.isna(x) or x.endswith('.com') else x + '.com')
display(df_2024_1.head())
# Out:
#             name                         Email      avaliacao  \
# 0  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 1  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 2  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 3  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
# 4  vitor.gabriel  vitor.gabriel@rocketcorp.com  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0       Organização no Trabalho             5.0
# 1            Atender aos prazos             5.0
# 2            Sentimento de Dono             5.0
# 3  Resiliencia nas adversidades             2.0
# 4                           NaN             5.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0  - Durante o ciclo, lidero a organização das en...
# 1  - No critério Imagem, tive uma atuação consist...
# 2  - No critério Iniciativa, tive uma atuação con...
# ...

# %% [markdown]
# ## Save updated 2024 1.xlsx
#
# ### Subtask:
# Save the updated 2024_1 DataFrame back to "2024_1_cleaned_final.xlsx".

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to the specified output path without the index.

# %%
output_path_2024_1 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_1_cleaned_final.xlsx"
df_2024_1.to_excel(output_path_2024_1, index=False)

# %% [markdown]
# ## Load cleaned 2024 2.xlsx
#
# ### Subtask:
# Load the cleaned "2024_2_cleaned_final.xlsx" file into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the specified Excel file into a DataFrame and display the first few rows.

# %%
df_2024_2 = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2_cleaned_final.xlsx")
df_2024_2 = df_2024_2[~df_2024_2['avaliacao'].astype(str).str.contains('perfil', case=False, na=False)]
df_2024_2['email'] = df_2024_2['email'].str.replace(r'\.\.', '.', regex=True)
display(df_2024_2.head())
# Out:
#             name                         email      avaliacao  \
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0       Organização no Trabalho             1.0
# 1            Atender aos prazos             3.0
# 2            Sentimento de Dono             4.0
# 3  Resiliencia nas adversidades             4.0
# 4                           NaN             4.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0  - Tenho dificuldade em manter o controle das t...
# 1  - Atuei de forma adequada no critério Imagem. ...
# 2  - No critério Iniciativa, estou em processo de...
# ...

# %% [markdown]
# ## Add .com to email column in 2024 2.xlsx
#
# ### Subtask:
# Add ".com" to the 'Email' column for entries that are missing it in the 2024_2 DataFrame.

# %% [markdown]
# **Reasoning**:
# Add '.com' to the 'Email' column for entries that are missing it in the 2024_2 DataFrame.

# %%
df_2024_2['Email'] = df_2024_2['Email'].apply(lambda x: x if pd.isna(x) or x.endswith('.com') else x + '.com')
display(df_2024_2.head())
# Out:
#             name                         Email      avaliacao  \
# 0  lucas.gabriel  lucas.gabriel@rocketcorp.com         Perfil
# 1  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 2  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 3  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
# 4  lucas.gabriel  lucas.gabriel@rocketcorp.com  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0                           NaN             NaN
# 1       Organização no Trabalho             1.0
# 2            Atender aos prazos             3.0
# 3            Sentimento de Dono             4.0
# 4  Resiliencia nas adversidades             4.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0                                                NaN
# 1  - Tenho dificuldade em manter o controle das t...
# 2  - Atuei de forma adequada no critério Imagem. ...
# ...

# %% [markdown]
# ## Save updated 2024 2.xlsx
#
# ### Subtask:
# Save the updated 2024_2 DataFrame back to "2024_2_cleaned_final.xlsx".

# %% [markdown]
# **Reasoning**:
# Save the modified df_2024_2 DataFrame to the specified Excel file path without including the index.

# %%
output_path_2024_2 = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2024_2_cleaned_final.xlsx"
df_2024_2.to_excel(output_path_2024_2, index=False)

# %% [markdown]
# ## Load cleaned 2025 1.xlsx
#
# ### Subtask:
# Load the cleaned "2025_1_cleaned_final.xlsx" file into a DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the specified Excel file into a pandas DataFrame and display the head to verify.

# %%
df_2025_1 = pd.read_excel("/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1_cleaned_final.xlsx")
df_2025_1 = df_2025_1[~df_2025_1['avaliacao'].astype(str).str.contains('perfil', case=False, na=False)]
df_2025_1['Email'] = df_2025_1['Email'].str.replace(r'\.\.', '.', regex=True)
display(df_2025_1.head())
# Out:
#              name                          Email      avaliacao  \
# 0  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 1  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 2  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 3  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 4  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0       Organização no Trabalho             1.0
# 1            Atender aos prazos             4.0
# 2            Sentimento de Dono             5.0
# 3  Resiliencia nas adversidades             4.0
# 4                           NaN             3.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0  - Tenho dificuldade em manter o controle das t...
# 1  - No critério Imagem, estou em processo de des...
# 2  - No critério Iniciativa, tive uma atuação con...
# ...

# %% [markdown]
# ## Add .com to email column in 2025 1.xlsx
#
# ### Subtask:
# Add ".com" to the 'Email' column for entries that are missing it in the 2025_1 DataFrame.

# %% [markdown]
# **Reasoning**:
# Add ".com" to entries in the 'Email' column of df_2025_1 that do not end with ".com" and are not NaN, then display the head to verify.

# %%
df_2025_1['Email'] = df_2025_1['Email'].apply(lambda x: x if pd.isna(x) or x.endswith('.com') else x + '.com')
display(df_2025_1.head())
# Out:
#              name                          Email      avaliacao  \
# 0  vitória.aragão  vitória.aragão@rocketcorp.com         Perfil
# 1  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 2  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 3  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
# 4  vitória.aragão  vitória.aragão@rocketcorp.com  Autoavaliação
#
#                        CRITÉRIO  AUTO-AVALIAÇÃO  \
# 0                           NaN             NaN
# 1       Organização no Trabalho             1.0
# 2            Atender aos prazos             4.0
# 3            Sentimento de Dono             5.0
# 4  Resiliencia nas adversidades             4.0
#
#   DADOS E FATOS DA AUTO-AVALIAÇÃO\nCITE, DE FORMA OBJETIVA, CASOS E SITUAÇÕES REAIS  \
# 0                                                NaN
# 1  - Tenho dificuldade em manter o controle das t...
# 2  - No critério Imagem, estou em processo de des...
# ...

# %% [markdown]
# ## Save updated 2025 1.xlsx
#
# ### Subtask:
# Save updated 2025 1.xlsx

# %% [markdown]
# **Reasoning**:
# Save the modified DataFrame to a new Excel file without the index.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1_cleaned_final.xlsx"
df_2025_1.to_excel(output_path, index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * The 'Email' column in the DataFrames loaded from "2024\_1\_cleaned\_final.xlsx", "2024\_2\_cleaned\_final.xlsx", and "2025\_1\_cleaned\_final.xlsx" were successfully updated by adding ".com" to entries that were missing the suffix.
# * The modified DataFrames were successfully saved back to their original file paths with the index excluded.
#
# ### Insights or Next Steps
#
# * This process ensures email address consistency across the three datasets, which is beneficial for subsequent data merging or analysis tasks.
# * Consider implementing a similar check and update process for other columns that might require consistent formatting or data cleaning.

# %%
output_path = "/content/drive/MyDrive/Untitled Folder/ciclos/Ciclos merge/Cleaned/2025_1_cleaned_final.xlsx"
df_2025_1.to_excel(output_path, index=False)
